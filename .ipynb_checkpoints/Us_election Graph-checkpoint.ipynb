# %%
import pandas as pd 
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.colors as pltc
import geopandas as gpd
import descartes as des

# %%
trump_csv = pd.read_csv("/home/mozes721/Desktop/US_Elections/trump.csv")
biden_csv =pd.read_csv("/home/mozes721/Desktop/US_Elections/biden.csv")
#change the vote row 
trump_csv.apply(lambda x: x.replace(',', '.') for x in trump_csv)

trumpcsv_adjusted = trump_csv.drop('Unnamed: 0', axis=1)
# trumpcsv_adjusted.apply(lambda x: x.replace(',', '.') for x in trumpcsv_adjusted[''])
# trump_data = trumpcsv_adjusted.apply(lambda x: x.replace(',', '.') for x in trumpcsv_adjusted[''])
bidencsv_adjusted = biden_csv.drop('Unnamed: 0', axis=1)
# bidencsv_adjusted.apply(lambda x: x.replace(',', '.') for x in bidencsv_adjusted[''])
# print(trumpcsv_adjusted)

# bidencsv_adjusted = bidencsv.drop('Unnamed: 0', axis=1)
# trump_excel = trump_excel.loc[:, ~trump_excel.columns.str.contains('Unnamed')]
# biden_excel = biden_excel.loc[:, ~biden_excel.columns.str.contains('Unnamed')]


print(trumpcsv_adjusted)
# Out:
#              state      votes percent
# 0          Alabama  1,441,170   62.2%
# 1           Alaska    189,543   53.1%
# 2          Arizona  1,661,686   49.1%
# 3         Arkansas    760,647   62.4%
# 4       California  5,982,194   34.3%
# 5         Colorado  1,364,471   41.9%
# 6      Connecticut    715,291   39.2%
# 7         Delaware    200,603   39.8%
# 8          Florida  5,668,731   51.2%
# 9          Georgia  2,461,837   49.3%
# 10          Hawaii    196,602   34.3%
# 11           Idaho    554,128   63.9%
# 12        Illinois  2,438,943   40.5%
# 13         Indiana  1,729,516   57.1%
# 14            Iowa    897,672   53.2%
# 15          Kansas    752,933   56.5%
# 16        Kentucky  1,326,646   62.1%
# 17       Louisiana  1,255,776   58.5%
# 18           Maine    360,480     44%
# 19        Maryland    976,414   32.4%
# 20   Massachusetts  1,167,202   32.3%
# 21        Michigan  2,649,852   47.8%
# 22       Minnesota  1,484,065   45.4%
# 23     Mississippi    756,789   57.6%
# 24        Missouri  1,718,282   56.8%
# 25         Montana    343,647   56.9%
# 26        Nebraska    556,846   58.5%
# 27          Nevada    669,890   47.7%
# 28   New-Hampshire    365,660   45.5%
# 29      New-Jersey  1,883,260   41.4%
# 30      New-Mexico    401,894   43.5%
# 31        New-York  3,039,466   41.1%
# 32  North-Carolina  2,758,775   50.1%
# 33    North-Dakota    235,595   65.5%
# 34            Ohio  3,154,834   53.3%
# 35        Oklahoma  1,020,280   65.4%
# 36          Oregon    958,448   40.7%
# 37    Pennsylvania  3,378,263   48.8%
# 38    Rhode-Island    199,922   38.8%
# 39  South-Carolina  1,385,103   55.1%
# 40    South-Dakota    261,043   61.8%
# 41       Tennessee  1,849,556   60.7%
# 42           Texas  5,890,347   52.1%
# 43            Utah    865,140   58.2%
# 44         Vermont    112,704   30.8%
# 45        Virginia  1,962,430   44.2%
# 46      Washington  1,584,651     39%
# 47   Washington-Dc     18,586    5.4%
# 48   West-Virginia    545,382   68.6%
# 49       Wisconsin  1,610,184   48.9%
# 50         Wyoming    193,559   70.4%

# %%
states_data = gpd.read_file('State_map/States_shapefile.shp')

# %%
states = []

trump_votes = []
trump_percent = []


for state in trump_excel.iloc[:,0]:
    states.append(state)




for vote in trump_excel.iloc[:,1]:
    trump_votes.append(vote)


for percent in trump_excel.iloc[:,2]:
    trump_percent.append(percent)
votes = df.astype(float)
df = pd.DataFrame(votes)
ax = df.plot.bar(rot=0, color= 'green')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-a8a8ce600085> in <module>
#       5
#       6
# ----> 7 for state in trump_excel.iloc[:,0]:
#       8     states.append(state)
#       9
#
# NameError: name 'trump_excel' is not defined

# %%
states_data.plot()
# Out:
# <AxesSubplot:>

# %%
for items in trumpcsv_adjusted['state'].tolist():
    state_list = states_data.tolist()
    if items in state_list:
        pass
    else:
        print(item + 'Not in list')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-7f90d8344156> in <module>
#       1 for items in trumpcsv_adjusted['state'].tolist():
# ----> 2     state_list = states_data.tolist()
#       3     if items in state_list:
#       4         pass
#       5     else:
#
# ~/Desktop/US_Elections/venv/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'GeoDataFrame' object has no attribute 'tolist'

# %%
states = []

trump_votes = []

trump_percent = []
#get each column value
for state in trumpcsv_adjusted.iloc[:,0]:
    states.append(state)


for vote in trumpcsv_adjusted.iloc[:,1]:
    trump_votes.append(vote)


for percent in trumpcsv_adjusted.iloc[:,2]:
    trump_percent.append(percent)


biden_votes = []
biden_percent = []

for vote in bidencsv_adjusted.iloc[:,1]:
    biden_votes.append(vote)


for percent in bidencsv_adjusted.iloc[:,2]:
    biden_percent.append(percent)
#trump_votes_float = [float(item) for item in trump_votes]
# Out:
# ['1,441,170', '189,543', '1,661,686', '760,647', '5,982,194', '1,364,471', '715,291', '200,603', '5,668,731', '2,461,837', '196,602', '554,128', '2,438,943', '1,729,516', '897,672', '752,933', '1,326,646', '1,255,776', '360,480', '976,414', '1,167,202', '2,649,852', '1,484,065', '756,789', '1,718,282', '343,647', '556,846', '669,890', '365,660', '1,883,260', '401,894', '3,039,466', '2,758,775', '235,595', '3,154,834', '1,020,280', '958,448', '3,378,263', '199,922', '1,385,103', '261,043', '1,849,556', '5,890,347', '865,140', '112,704', '1,962,430', '1,584,651', '18,586', '545,382', '1,610,184', '193,559']

# %%
#adjusting trying to convert to float value
#convert to float
# x = np.array([trump_votes])
# votes = x.astype(np.float)

plt.pie(trump_values_dot, labels=states)
plt.title("Trump Election chart by votes")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-d355a7c542d5> in <module>
#       4 # votes = x.astype(np.float)
#       5
# ----> 6 plt.pie(trump_values_dot, labels=states)
#       7 plt.title("Trump Election chart by votes")
#
# ~/Desktop/US_Elections/venv/lib/python3.8/site-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2825         textprops=None, center=(0, 0), frame=False,
#    2826         rotatelabels=False, *, normalize=None, data=None):
# -> 2827     return gca().pie(
#    2828         x, explode=explode, labels=labels, colors=colors,
#    2829         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ~/Desktop/US_Elections/venv/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/Desktop/US_Elections/venv/lib/python3.8/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    2993         # The use of float32 is "historical", but can't be changed without
#    2994         # regenerating the test baselines.
# -> 2995         x = np.asarray(x, np.float32)
#    2996         if x.ndim > 1:
#    2997             raise ValueError("x must be 1D")
#
# ~/Desktop/US_Elections/venv/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# ValueError: could not convert string to float: '1.441.170'
